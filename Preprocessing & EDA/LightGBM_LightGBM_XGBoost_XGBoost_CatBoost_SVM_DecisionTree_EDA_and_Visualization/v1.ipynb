# %%
# !pip install flaml[automl] matplotlib openml
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Collecting openml
#   Downloading openml-0.15.1-py3-none-any.whl.metadata (10 kB)
# Collecting flaml[automl]
#   Downloading FLAML-2.3.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: NumPy>=1.17 in /usr/local/lib/python3.11/dist-packages (from flaml[automl]) (1.26.4)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from flaml[automl]) (4.5.0)
# Requirement already satisfied: xgboost<3.0.0,>=0.90 in /usr/local/lib/python3.11/dist-packages (from flaml[automl]) (2.0.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from flaml[automl]) (1.15.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from flaml[automl]) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from flaml[automl]) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Collecting liac-arff>=2.4.0 (from openml)
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting xmltodict (from openml)
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openml) (2.32.3)
# Collecting minio (from openml)
#   Downloading minio-7.2.15-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from openml) (19.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openml) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from NumPy>=1.17->flaml[automl]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from NumPy>=1.17->flaml[automl]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from NumPy>=1.17->flaml[automl]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from NumPy>=1.17->flaml[automl]) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from NumPy>=1.17->flaml[automl]) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from NumPy>=1.17->flaml[automl]) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->flaml[automl]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->flaml[automl]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->flaml[automl]) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->flaml[automl]) (3.6.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from minio->openml) (2025.4.26)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from minio->openml) (2.4.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from minio->openml) (23.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.11/dist-packages (from minio->openml) (3.22.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from minio->openml) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openml) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openml) (3.10)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->minio->openml) (21.2.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->NumPy>=1.17->flaml[automl]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->NumPy>=1.17->flaml[automl]) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->NumPy>=1.17->flaml[automl]) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->NumPy>=1.17->flaml[automl]) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->NumPy>=1.17->flaml[automl]) (2024.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml) (2.22)
# Downloading openml-0.15.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 5.4 MB/s eta 0:00:00
# Downloading FLAML-2.3.5-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 12.7 MB/s eta 0:00:00
# Downloading minio-7.2.15-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 4.9 MB/s eta 0:00:00
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: liac-arff
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11717 sha256=25200aea0741b7d836777dddd5a91e40f838de8715392a0855db714ad996627f
#   Stored in directory: /root/.cache/pip/wheels/00/23/31/5e562fce1f95aabe57f2a7320d07433ba1cd152bcde2f6a002
# Successfully built liac-arff
# Installing collected packages: xmltodict, liac-arff, minio, flaml, openml
# Successfully installed flaml-2.3.5 liac-arff-2.5.0 minio-7.2.15 openml-0.15.1 xmltodict-0.14.2

# %%
import warnings
warnings.simplefilter(action='ignore')

import os
import requests
import joblib

import numpy
import pandas

import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
from flaml import AutoML

from flaml.automl.model import LGBMEstimator

# %%
from catboost import CatBoostRegressor ,Pool
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.linear_model import ElasticNetCV, LassoCV, RidgeCV
from sklearn.svm import SVR

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score

from sklearn.pipeline import make_pipeline
from sklearn.model_selection import KFold, cross_val_score
from sklearn.tree import DecisionTreeRegressor

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectFromModel

from sklearn.impute import SimpleImputer
import sklearn.linear_model as linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
train_x = pandas.read_csv('/kaggle/input/crypto-models/data/X_train.csv')
train_y = pandas.read_csv('/kaggle/input/crypto-models/data/y_train.csv')
test_x = pandas.read_csv('/kaggle/input/crypto-models/data/X_test.csv')
test_y = pandas.read_csv('/kaggle/input/crypto-models/data/y_test.csv')
test = pandas.read_csv('/kaggle/input/drw-crypto-data/test.csv')

# %%
automl = AutoML()

settings = {
    "time_budget": 2000,
    "metric": "mae",
    "estimator_list": ["lgbm"],
    "task": "regression",
    "log_file_name": "experiment.log",
    "seed": 41,
    "eval_method": "cv"
}
automl.fit(numpy.array(train_x), numpy.array(train_y), **settings)
# Out:
# [flaml.automl.logger: 07-07 05:48:46] {1752} INFO - task = regression
# [flaml.automl.logger: 07-07 05:48:46] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 07-07 05:48:47] {1862} INFO - Minimizing error metric: mae
# [flaml.automl.logger: 07-07 05:48:47] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 07-07 05:48:47] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 07-07 05:48:58] {2417} INFO - Estimated sufficient time budget=114321s. Estimated necessary time budget=114s.
# [flaml.automl.logger: 07-07 05:48:58] {2466} INFO -  at 11.9s,	estimator lgbm's best error=0.6373,	best estimator lgbm's best error=0.6373
# [flaml.automl.logger: 07-07 05:48:58] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 07-07 05:49:10] {2466} INFO -  at 24.1s,	estimator lgbm's best error=0.6307,	best estimator lgbm's best error=0.6307
# [flaml.automl.logger: 07-07 05:49:10] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 07-07 05:49:21] {2466} INFO -  at 35.3s,	estimator lgbm's best error=0.6307,	best estimator lgbm's best error=0.6307
# [flaml.automl.logger: 07-07 05:49:21] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 07-07 05:49:33] {2466} INFO -  at 46.7s,	estimator lgbm's best error=0.6304,	best estimator lgbm's best error=0.6304
# [flaml.automl.logger: 07-07 05:49:33] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 07-07 05:49:45] {2466} INFO -  at 59.1s,	estimator lgbm's best error=0.6298,	best estimator lgbm's best error=0.6298
# [flaml.automl.logger: 07-07 05:49:45] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 07-07 05:49:57] {2466} INFO -  at 71.2s,	estimator lgbm's best error=0.6298,	best estimator lgbm's best error=0.6298
# [flaml.automl.logger: 07-07 05:49:57] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 07-07 05:50:10] {2466} INFO -  at 83.8s,	estimator lgbm's best error=0.6183,	best estimator lgbm's best error=0.6183
# [flaml.automl.logger: 07-07 05:50:10] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 07-07 05:50:22] {2466} INFO -  at 95.5s,	estimator lgbm's best error=0.6183,	best estimator lgbm's best error=0.6183
# [flaml.automl.logger: 07-07 05:50:22] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 07-07 05:50:36] {2466} INFO -  at 110.2s,	estimator lgbm's best error=0.6087,	best estimator lgbm's best error=0.6087
# [flaml.automl.logger: 07-07 05:50:36] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 07-07 05:50:52] {2466} INFO -  at 126.0s,	estimator lgbm's best error=0.6087,	best estimator lgbm's best error=0.6087
# [flaml.automl.logger: 07-07 05:50:52] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 07-07 05:51:08] {2466} INFO -  at 141.7s,	estimator lgbm's best error=0.5666,	best estimator lgbm's best error=0.5666
# [flaml.automl.logger: 07-07 05:51:08] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 07-07 05:51:29] {2466} INFO -  at 163.2s,	estimator lgbm's best error=0.5014,	best estimator lgbm's best error=0.5014
# [flaml.automl.logger: 07-07 05:51:29] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 07-07 05:51:45] {2466} INFO -  at 179.0s,	estimator lgbm's best error=0.5014,	best estimator lgbm's best error=0.5014
# [flaml.automl.logger: 07-07 05:51:45] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 07-07 05:52:10] {2466} INFO -  at 203.8s,	estimator lgbm's best error=0.5014,	best estimator lgbm's best error=0.5014
# [flaml.automl.logger: 07-07 05:52:10] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 07-07 05:52:35] {2466} INFO -  at 229.4s,	estimator lgbm's best error=0.3739,	best estimator lgbm's best error=0.3739
# [flaml.automl.logger: 07-07 05:52:35] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 07-07 05:52:50] {2466} INFO -  at 243.7s,	estimator lgbm's best error=0.3739,	best estimator lgbm's best error=0.3739
# [flaml.automl.logger: 07-07 05:52:50] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 07-07 05:53:49] {2466} INFO -  at 302.8s,	estimator lgbm's best error=0.2426,	best estimator lgbm's best error=0.2426
# [flaml.automl.logger: 07-07 05:53:49] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 07-07 05:58:18] {2466} INFO -  at 571.5s,	estimator lgbm's best error=0.2296,	best estimator lgbm's best error=0.2296
# [flaml.automl.logger: 07-07 05:58:18] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 07-07 05:59:16] {2466} INFO -  at 630.2s,	estimator lgbm's best error=0.2296,	best estimator lgbm's best error=0.2296
# [flaml.automl.logger: 07-07 05:59:16] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 07-07 06:07:47] {2466} INFO -  at 1140.8s,	estimator lgbm's best error=0.2296,	best estimator lgbm's best error=0.2296
# [flaml.automl.logger: 07-07 06:07:47] {2282} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 07-07 06:10:40] {2466} INFO -  at 1314.3s,	estimator lgbm's best error=0.1971,	best estimator lgbm's best error=0.1971
# [flaml.automl.logger: 07-07 06:10:40] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 07-07 06:13:03] {2466} INFO -  at 1457.3s,	estimator lgbm's best error=0.1898,	best estimator lgbm's best error=0.1898
# [flaml.automl.logger: 07-07 06:13:03] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 07-07 06:15:43] {2466} INFO -  at 1617.3s,	estimator lgbm's best error=0.1898,	best estimator lgbm's best error=0.1898
# [flaml.automl.logger: 07-07 06:15:43] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 07-07 06:17:01] {2466} INFO -  at 1695.3s,	estimator lgbm's best error=0.1898,	best estimator lgbm's best error=0.1898
# [flaml.automl.logger: 07-07 06:17:01] {2282} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 07-07 06:20:39] {2466} INFO -  at 1912.6s,	estimator lgbm's best error=0.1898,	best estimator lgbm's best error=0.1898
# [flaml.automl.logger: 07-07 06:21:11] {2724} INFO - retrain lgbm for 32.4s
# [flaml.automl.logger: 07-07 06:21:11] {2727} INFO - retrained model: LGBMRegressor(colsample_bytree=0.7477794715206952,
#               learning_rate=0.36191629785143264, max_bin=127,
#               min_child_samples=128, n_estimators=272, n_jobs=-1,
#               num_leaves=211, reg_alpha=0.8617972292163744, reg_lambda=1024.0,
#               verbose=-1)
# [flaml.automl.logger: 07-07 06:21:11] {2009} INFO - fit succeeded
# [flaml.automl.logger: 07-07 06:21:11] {2010} INFO - Time taken to find the best model: 1457.3284645080566

# %%
test_predictions = automl.predict(numpy.array(test))
test_predictions
# Out:
# array([ 0.23168773,  0.32588189, -0.09954037, ..., -0.10070319,
#         0.07940139,  1.12424096])

# %%
submission = pandas.DataFrame({
    'ID': [i for i in range(1, len(test)+1)],
    'prediction': test_predictions,
})
submission
# Out:
#             ID  prediction
# 0            1    0.231688
# 1            2    0.325882
# 2            3   -0.099540
# 3            4   -1.495627
# 4            5    0.594055
# ...        ...         ...
# 538145  538146    0.153917
# 538146  538147    0.388757
# 538147  538148   -0.100703
# 538148  538149    0.079401
# 538149  538150    1.124241
#
# [538150 rows x 2 columns]

# %%
submission.to_csv('lightautoml.csv', index = False)
